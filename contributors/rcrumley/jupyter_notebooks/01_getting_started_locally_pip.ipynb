# %% [markdown]
# # Getting Started Locally with Conda
#
# This tutorial will take you through the steps to set up an environment on your local machine using conda.

# %% [markdown]
# ### Step 1: Make sure Anaconda or Miniconda is your Python package/library manager
#
# Go to the following website for more details:
#
# https://docs.conda.io/projects/conda/en/latest/user-guide/install/download.html

# %% [markdown]
# ### Step 2: Create conda environment used during SnowEx Hackweek 2021
#
# 1) Download the JupyterHub environment file used during SnowEx Hackweek 2021
#
# https://github.com/snowex-hackweek/docker-image/blob/main/environment.yml
#
# 2) Create a directory system locally to store files, Jupyter Notebooks, scripts, etc (optional)
#     - For this tutorial our directory system looks like this:
#         - /data
#         - /scripts
#         - /jupyter_notebooks
#         - /environment
#
#
# 3) Copy the downloaded environment file to the /snowex_hw_21/environment folder
#
# 4) Open the file with a text editor and change the name of the environment to snowex21 (or any name of your choice)
#
# 5) Navigate to /snowex_hw_21/environment directory and create the environment using conda commands below:

# %%
# %%bash
#
# # change directory to the environment folder
# cd ../environment
# # print the working directory to check your location
# pwd
# # list the files
# ls
# Out:
# /Volumes/fortress_ryan/skill_development/snowex_2021/project/snowex21/environment
# environment.yml

# %%
# %%bash
#
# # It may take a while to install all the packages
# # Some of the packages/libraries did not install for me
# # so I commented them out an recreated the env for the purposes of this tutorial
# conda env create -f environment.yml

# %% [markdown]
# For more info a conda and conda environments, got to:
#
# Conda CheatSheet
# https://docs.conda.io/projects/conda/en/4.6.0/_downloads/52a95608c49671267e40c689e0bc00ca/conda-cheatsheet.pdf
#
# Conda environments
# https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#creating-an-environment-from-an-environment-yml-file

# %% [markdown]
# ### Step 3: Activate the new snowex21 environment

# %%
# %%bash
#
# # Once the environment snowex21 has been created, then activate it
# conda activate snowex21

# %% [markdown]
# ### Step 4: Check some things

# %%
# %%bash
#
# # Check to see if your environment has been set up correctly
# conda info -v
# Out:
#      active environment : snowex21
#     active env location : /Users/rcrumley/opt/miniconda3/envs/snowex21
#             shell level : 2
#        user config file : /Users/rcrumley/.condarc
#  populated config files :
#           conda version : 4.10.1
#     conda-build version : not installed
#          python version : 3.9.1.final.0
#        virtual packages : __osx=10.16=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /Users/rcrumley/opt/miniconda3  (writable)
#       conda av data dir : /Users/rcrumley/opt/miniconda3/etc/conda
#   conda av metadata url : https://repo.anaconda.com/pkgs/main
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-64
#                           https://repo.anaconda.com/pkgs/r/noarch
# ...

# %%
# %%bash
#
# # Check to see which packages/libraries are added to this environment
# conda list -v
# Out:
# # packages in environment at /Users/rcrumley/opt/miniconda3/envs/snowex21:
# #
# # Name                    Version                   Build  Channel
# affine                    2.3.0                      py_0    conda-forge
# aiobotocore               1.3.3              pyhd8ed1ab_0    conda-forge
# aiohttp                   3.7.4.post0      py38h96a0964_0    conda-forge
# aioitertools              0.7.1              pyhd8ed1ab_0    conda-forge
# alabaster                 0.7.12                     py_0    conda-forge
# alembic                   1.6.5              pyhd8ed1ab_0    conda-forge
# anyio                     3.2.1            py38h50d1736_0    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# appnope                   0.1.2            py38h50d1736_1    conda-forge
# argon2-cffi               20.1.0           py38h96a0964_2    conda-forge
# asciitree                 0.3.3                      py_2    conda-forge
# ...
